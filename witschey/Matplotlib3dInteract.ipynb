# %% [markdown]
# # Interactive control of Matplotlib 3d figures

# %% [markdown]
# This is an interactive version of this [example from the matplotlib gallery](http://matplotlib.org/examples/mplot3d/trisurf3d_demo.html).  We load and configure matplotlib:

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
plt.rcParams['figure.figsize'] = (10, 8)

# %% [markdown]
# Now we create a 3d axis object we can then manipulate without recomputing any of the data. This will produce a static image with matplotlib's default view angle:

# %%
n_angles = 36
n_radii = 8

# An array of radii
# Does not include radius r=0, this is to eliminate duplicate points
radii = np.linspace(0.125, 1.0, n_radii)

# An array of angles
angles = np.linspace(0, 2*np.pi, n_angles, endpoint=False)

# Repeat all angles for each radius
angles = np.repeat(angles[...,np.newaxis], n_radii, axis=1)

# Convert polar (radii, angles) coords to cartesian (x, y) coords
# (0, 0) is added here. There are no duplicate points in the (x, y) plane
x = np.append(0, (radii*np.cos(angles)).flatten())
y = np.append(0, (radii*np.sin(angles)).flatten())

# Pringle surface
z = np.sin(-x*y)

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(x, y, z, cmap=cm.jet, linewidth=0.2);

# %% [markdown]
# Now, we load IPython's facilities for interactive control.

# %%
from IPython.display import display
from IPython.html.widgets import interact

# %% [markdown]
# And we write a simple decorator that lets us control the two view angles, calling the `view_init` method of the Axis object (note: for better 3d interactivity, we'll toggle off the gray boxes):

# %%
ax.set_axis_off()

@interact(elev=(-90, 90), azim=(0, 360))
def view(elev, azim):
    ax.view_init(elev, azim)
    display(ax.figure)
